# %% [markdown]
# # ML Learning Playground
# This notebook summarizes the experiments performed while learning machine learning fundamentals.

# %% [markdown]
# ## 1. Linear Algebra & Probability Essentials
# Covered vectors, matrices, dot products, mean and variance using NumPy. Examples include computing dot products and basic statistics.

# %% [markdown]
# ## 2. Install and Verify PyTorch
# Installed the CPU build of PyTorch and confirmed import as well as version. Performed tiny tensor operations.

# %% [markdown]
# ## 3. Tiny Tensor Operations
# Basic tensor creation and manipulation were demonstrated (addition, multiplication, matrix multiply).

# %% [markdown]
# ## 4. Training a Simple Neural Network
# A one-layer network trained on synthetic data (y=2x) with PyTorch. Loss decreased over epochs, and final weight approximated 2.

# %% [markdown]
# ## 5. Understanding GPUs and CUDA
# Learned about GPU parallelism and CUDA. Installed CPU-only PyTorch; primer suggests installing CUDA toolkit if hardware available.

# %% [markdown]
# ## 6. CPU vs GPU Performance Comparison
# Ported training loop to Google Colab; observed significant speed-up on GPU compared to local CPU runtime (timings logged in Colab).

# %% [markdown]
# ## 7. Scikit-learn Classification with Iris Dataset
# Loaded Iris dataset, trained logistic regression, and achieved reasonable accuracy (~97%).

# %% [markdown]
# ## 8. Data Pipelines with Pandas
# Demonstrated creation and filtering of DataFrames, saved filtered data to CSV.

# %% [markdown]
# ## 9. Model Evaluation Metrics
# Used train/validation/test splits, computed confusion matrix, precision, and recall for classification.

# %% [markdown]
# ## 10. Pretrained Model Inference with Hugging Face
# Loaded a small transformer model and ran a sentiment-analysis example.

# %% [markdown]
# ## 11. Experiment Documentation and Requirements
# Requirements listed in `requirements.txt`; README describes the project. This notebook summarizes the key steps.
