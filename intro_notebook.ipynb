# %% [markdown]
# # Quick Intro to Jupyter
# Import numpy and plot a tiny array.

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.array([1, 2, 4, 3, 5])
plt.plot(data)
plt.title('My Tiny Array')
plt.show()
